# %%
1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
solution:-

 *  - expression

 "hello"- value

  -87.8 - value

  - - expression

  / - expression

  + - expression

   6 - value


2. What is the difference between string and variable?

solution:-

  string can be written in quotes as mention
   "mayank" (or) 'mayank'

  variable is a thing which helps in holding a data in entity.



3.Describe three different data forms?
 
solution:- int,float,list,complex


    
4. What is an expression made up of? What do all expressions do?

solution:- expression is madeup of values,containers,and mathematical operators



5. This assignment statements, like spam = 10. What is the difference between an
expression and a statement?

solution:- as we discussed above,expressions are values,containers,and mathematical operators. whereas,statement is like a command which python executes like list


    
6. After running the following code, what does the variable bacon contain?
bacon = 22 bacon + 1

solution:- 23


7. What should the values of the following two terms be?
'spam' + 'spamspam' 'spam'* 3

solution:- same value- spamspamspam


8. Why is eggs a valid variable name while 100 is invalid?

solution:-because we cant give a integer name to a variable.


9. What three functions can be used to get the integer, floating-point number, or string
version of a value?

solution:- string() int() float()


10. Why does this expression cause an error? How can you fix it?
'I have eaten'+99+'burritos'

solution:- because 99 is a integer it cannot be connected with strings. typecasting should be done
 for ex- 'I have eaten'+str(99)+'burritos'
